# %%
import pandas as pd
odi = pd.read_csv('odi.csv')

# %%
odi.head(20)
# Out:
#     mid        date                                 venue bat_team bowl_team  \
# 0     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 1     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 2     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 3     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 4     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 5     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 6     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 7     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 8     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 9     1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 10    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 11    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 12    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 13    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 14    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 15    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 16    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 17    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 18    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
# 19    1  2006-06-13  Civil Service Cricket Club, Stormont  England   Ireland
#
#            batsman            bowler  runs  wickets  overs  runs_last_5  \
# 0   ME Trescothick       DT Johnston     0        0    0.1            0
# 1   ME Trescothick       DT Johnston     0        0    0.2            0
# 2   ME Trescothick       DT Johnston     4        0    0.3            4
# 3   ME Trescothick       DT Johnston     6        0    0.4            6
# 4   ME Trescothick       DT Johnston     6        0    0.5            6
# 5   ME Trescothick       DT Johnston     6        0    0.6            6
# 6         EC Joyce  D Langford-Smith     6        0    1.1            6
# 7         EC Joyce  D Langford-Smith     6        0    1.2            6
# 8         EC Joyce  D Langford-Smith     6        0    1.3            6
# 9         EC Joyce  D Langford-Smith     7        0    1.3            7
# 10        EC Joyce  D Langford-Smith     8        0    1.4            8
# 11  ME Trescothick  D Langford-Smith     8        0    1.5            8
# 12  ME Trescothick  D Langford-Smith     9        0    1.6            9
# 13  ME Trescothick       DT Johnston    10        0    2.0           10
# 14  ME Trescothick       DT Johnston    10        0    2.1           10
# 15  ME Trescothick       DT Johnston    11        0    2.2           11
# 16        EC Joyce       DT Johnston    11        0    2.3           11
# 17        EC Joyce       DT Johnston    12        0    2.4           12
# 18  ME Trescothick       DT Johnston    12        0    2.5           12
# 19  ME Trescothick       DT Johnston    16        0    2.6           16
#
#     wickets_last_5  striker  non-striker  total
# 0                0        0            0    301
# 1                0        0            0    301
# 2                0        0            0    301
# 3                0        0            0    301
# 4                0        0            0    301
# 5                0        0            0    301
# 6                0        0            0    301
# 7                0        0            0    301
# 8                0        0            0    301
# 9                0        0            0    301
# 10               0        1            0    301
# 11               0        1            0    301
# 12               0        1            1    301
# 13               0        1            1    301
# 14               0        1            1    301
# 15               0        1            1    301
# 16               0        1            1    301
# 17               0        2            1    301
# 18               0        2            1    301
# 19               0        5            2    301

# %%
odi.shape
# Out:
# (22656, 15)

# %%
odi.isnull().sum()
# Out:
# mid               0
# date              0
# venue             0
# bat_team          0
# bowl_team         0
# batsman           0
# bowler            0
# runs              0
# wickets           0
# overs             0
# runs_last_5       0
# wickets_last_5    0
# striker           0
# non-striker       0
# total             0
# dtype: int64

# %%
odi.describe()
# Out:
#                 mid          runs       wickets         overs   runs_last_5  \
# count  22656.000000  22656.000000  22656.000000  22656.000000  22656.000000
# mean      37.511785    114.206391      2.885681     24.333413     23.019288
# std       21.531002     78.152709      2.210665     14.364036     11.133671
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%       19.000000     49.000000      1.000000     12.100000     16.000000
# 50%       38.000000    105.000000      3.000000     24.300000     22.000000
# 75%       56.000000    168.000000      4.000000     36.500000     29.000000
# max       75.000000    434.000000     10.000000     49.600000     84.000000
#
#        wickets_last_5       striker   non-striker         total
# count    22656.000000  22656.000000  22656.000000  22656.000000
# mean         0.636079     35.213674     12.068547    256.071239
# std          0.793998     27.008223     14.384122     61.429235
# min          0.000000      0.000000      0.000000    118.000000
# 25%          0.000000     13.000000      2.000000    218.000000
# 50%          0.000000     30.000000      7.000000    255.000000
# 75%          1.000000     51.000000     17.000000    288.000000
# max          5.000000    164.000000    108.000000    434.000000

# %%
odi['bat_team'].unique()
# Out:
# array(['England', 'Pakistan', 'Sri Lanka', 'Australia', 'South Africa',
#        'New Zealand', 'Bangladesh', 'West Indies', 'India', 'Zimbabwe',
#        'Ireland', 'Scotland'], dtype=object)

# %%
odi = odi[odi['overs']>=15.0]

# %%
odi[['venue', 'bat_team', 'bowl_team', 'batsman', 'bowler',
       'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
       'non-striker']][:50].plot(kind = 'area', figsize = (10,10), stacked = False)
# Out:
# <AxesSubplot:>

# %%
x = odi.iloc[:,[7, 8, 9, 10, 12, 13]].values
y = odi.iloc[:, 14].values

# %%
x
# Out:
# array([[ 99. ,   3. ,  15.1,  32. ,  55. ,   0. ],
#        [101. ,   3. ,  15.2,  33. ,  57. ,   0. ],
#        [101. ,   3. ,  15.3,  33. ,  57. ,   0. ],
#        ...,
#        [323. ,   7. ,  49.4,  43. ,   6. ,   0. ],
#        [327. ,   7. ,  49.5,  47. ,  10. ,   0. ],
#        [331. ,   7. ,  49.6,  51. ,  14. ,   0. ]])

# %%
y
# Out:
# array([301, 301, 301, ..., 331, 331, 331], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 7)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

model = LinearRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_test)

print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : 0.7416830327510548
# Testing Accuracy : 0.7364349458963984

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100,max_features=None)
model.fit(x_train,y_train)

y_pred = model.predict(x_test)

print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : 0.997417630879189
# Testing Accuracy : 0.9799644480750769

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'n_estimators': [100, 200, 300, 1000]
}
rf = RandomForestRegressor()
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(x_train, y_train)
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# {'bootstrap': True, 'max_depth': 100, 'max_features': 3, 'n_estimators': 300}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=100, max_features=3, n_estimators=300)

# %%
grid_search.score(x_test, y_test)
# Out:
# 0.9828847154001726
